# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
import warnings
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv('./20190516113616.csv',engine='python')

# %%
df.head()
# Out:
#     지점                일시  기온(°C)  기온 QC플래그  강수량(mm)  강수량 QC플래그  풍속(m/s)  \
# 0  133  2019-01-01 01:00    -4.4       0.0      NaN        NaN      0.6
# 1  133  2019-01-01 02:00    -3.9       0.0      NaN        NaN      0.4
# 2  133  2019-01-01 03:00    -4.4       0.0      NaN        NaN      1.0
# 3  133  2019-01-01 04:00    -5.1       0.0      NaN        NaN      0.7
# 4  133  2019-01-01 05:00    -5.5       0.0      NaN        NaN      0.0
#
#    풍속 QC플래그  풍향(16방위)  풍향 QC플래그  ...  최저운고(100m )  시정(10m)  지면상태(지면상태코드)  \
# 0       NaN        90       NaN  ...         11.0     1357           NaN
# 1       NaN         0       NaN  ...         10.0     1471           NaN
# 2       NaN       200       NaN  ...         11.0     1345           NaN
# 3       NaN       320       NaN  ...         11.0     1310           NaN
# 4       NaN         0       NaN  ...         11.0     1210           NaN
#
#    현상번호(국내식)  지면온도(°C)  지면온도 QC플래그  5cm 지중온도(°C)  10cm 지중온도(°C)  \
# 0        NaN      -3.2         0.0          -1.7           -1.2
# 1        NaN      -3.4         0.0          -1.6           -1.1
# 2        NaN      -4.9         0.0          -2.0           -1.2
# 3        NaN      -6.2         0.0          -2.6           -1.3
# 4        NaN      -6.3         0.0          -2.8           -1.4
#
#    20cm 지중온도(°C)  30cm 지중온도(°C)
# 0            0.6            1.5
# 1            0.5            1.5
# 2            0.6            1.5
# 3            0.5            1.5
# 4            0.6            1.5
#
# [5 rows x 36 columns]

# %%
f,ax=plt.subplots(figsize=(18,18))
sns.heatmap(df.corr(),annot=True,linewidths=.5,fmt='.2f',ax=ax)
plt.show()
